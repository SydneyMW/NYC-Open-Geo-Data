# %% [markdown]
# # Open Shape File

# %%
#!pip install geopandas
#!pip install descartes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from sodapy import Socrata
from shapely.geometry import Point, Polygon

# %%
## Fetch data from API
#client = Socrata("data.cityofnewyork.us", None)
#results = client.get("e42i-6hpb", limit=10000)
#results_df = pd.DataFrame.from_records(results)

# %%
shapefile = gpd.read_file('./shapefile/geo_export_426d25b7-267f-47a3-88cc-132bf267b23d.shp')

# %%
fig, ax = plt.subplots(figsize = (15, 15))
shapefile.plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
roads = gpd.read_file('./shapefile/nyu_2451_34499.shp')

# %%
fig, ax = plt.subplots(figsize = (15, 15))
roads.plot(ax=ax, markersize=1, alpha=0.2)
plt.show()

# %%
subway_stops = gpd.read_file('./shapefile/nyu_2451_34503.shp')
subway_routes = gpd.read_file('./shapefile/nyu_2451_34758.shp')

# %%
fig, ax = plt.subplots(figsize = (15, 15))
subway_stops.plot(ax=ax, alpha=0.5, color='purple', markersize=15)
subway_routes.plot(ax=ax, alpha=0.5)
# Out:
# <AxesSubplot:>
